# %%
# Mapping characters to their respective numbers
charstr = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
chars = list(charstr)
nums = [str(i) for i in range(0, 26)]

# Function to convert character to its corresponding number
def char_to_num(char):
    return chars.index(char)

# Function to convert number to its corresponding character
def num_to_char(num):
    return chars[num]

# Encryption function
def encrypt(plaintext, key):
    # Ensure the key length is at least as long as the plaintext
    if len(key) < len(plaintext):
        raise ValueError("Key length must be greater than or equal to plaintext length")
    
    # Perform modular addition
    cipher_text = ''
    for i in range(len(plaintext)):
        plain_num = char_to_num(plaintext[i])
        key_num = char_to_num(key[i])
        cipher_num = (plain_num + key_num) % 26
        cipher_text += num_to_char(cipher_num)
    
    return cipher_text

# Decryption function
def decrypt(cipher_text, key):
    # Ensure the key length is at least as long as the ciphertext
    if len(key) < len(cipher_text):
        raise ValueError("Key length must be greater than or equal to ciphertext length")
    
    # Perform modular subtraction
    plaintext = ''
    for i in range(len(cipher_text)):
        cipher_num = char_to_num(cipher_text[i])
        key_num = char_to_num(key[i])
        plain_num = (cipher_num - key_num) % 26
        plaintext += num_to_char(plain_num)
    
    return plaintext

# Taking input from the user
plaintext = input("Enter the plaintext (only capital letters): ")
key = "THISISANEXAMPLEKEYINCOMPUTERSECURITYEXAM"

cipher = encrypt(plaintext, key)
print(f"Plaintext: {plaintext}")
print(f"Key: {key}")
print(f"Cipher: {cipher}")


# Decrypt the cipher text
cipher = input("Enter the cipher text (only capital letters): ")
decrypted_text = decrypt(cipher, key)
print(f"Decrypted text: {decrypted_text}")

# Verify the decryption
if decrypted_text == plaintext:
    print("Decryption successful: The decrypted text matches the original plaintext.")
else:
    print("Decryption failed: The decrypted text does not match the original plaintext.")
# Out:
# Enter the plaintext (only capital letters): NANCY
# Plaintext: NANCY
# Key: THISISANEXAMPLEKEYINCOMPUTERSECURITYEXAM
# Cipher: GHVUG
# Enter the cipher text (only capital letters): GHVUG
# Decrypted text: NANCY
# Decryption successful: The decrypted text matches the original plaintext.

# %%
# Mapping characters to their respective numbers
charstr = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
chars = list(charstr)
nums = [str(i) for i in range(0, 26)]

# Function to convert character to its corresponding number
def char_to_num(char):
    return chars.index(char)

# Function to convert number to its corresponding character
def num_to_char(num):
    return chars[num]

# Encryption function
def encrypt(plaintext, key):
    if len(key) < len(plaintext):
        raise ValueError("Key length must be greater than or equal to plaintext length")
    
    cipher_text = ''
    for i in range(len(plaintext)):
        plain_num = char_to_num(plaintext[i])
        key_num = char_to_num(key[i])
        cipher_num = (plain_num + key_num) % 26
        cipher_text += num_to_char(cipher_num)
    
    return cipher_text

# Decryption function
def decrypt(ciphertext, key):
    if len(key) < len(ciphertext):
        raise ValueError("Key length must be greater than or equal to ciphertext length")
    
    plaintext = ''
    for i in range(len(ciphertext)):
        cipher_num = char_to_num(ciphertext[i])
        key_num = char_to_num(key[i])
        plain_num = (cipher_num - key_num + 26) % 26
        plaintext += num_to_char(plain_num)
    
    return plaintext

# Main function to choose between encryption and decryption
def main():
    print("Choose an option:")
    print("1. Encrypt")
    print("2. Decrypt")
    choice = input("Enter 1 or 2: ")

    if choice == '1':
        plaintext = input("Enter the plaintext (only capital letters): ")
        key = input("Enter the key (must be at least as long as the plaintext): ")
        try:
            cipher = encrypt(plaintext, key)
            print(f"Plaintext: {plaintext}")
            print(f"Key: {key}")
            print(f"Cipher: {cipher}")
        except ValueError as e:
            print(e)
    elif choice == '2':
        ciphertext = input("Enter the ciphertext (only capital letters): ")
        key = input("Enter the key (must be at least as long as the ciphertext): ")
        try:
            plaintext = decrypt(ciphertext, key)
            print(f"Ciphertext: {ciphertext}")
            print(f"Key: {key}")
            print(f"Plaintext: {plaintext}")
        except ValueError as e:
            print(e)
    else:
        print("Invalid choice. Please enter 1 or 2.")

main()
# Out:
# Choose an option:
# 1. Encrypt
# 2. Decrypt
# Enter 1 or 2: 1
# Enter the plaintext (only capital letters): HELLO
# Enter the key (must be at least as long as the plaintext): SECRET
# Plaintext: HELLO
# Key: SECRET
# Cipher: ZINCS

# %%
# Mapping characters to their respective numbers
charstr = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
chars = list(charstr)
nums = [str(i) for i in range(0, 26)]

# Function to convert character to its corresponding number
def char_to_num(char):
    return chars.index(char)

# Function to convert number to its corresponding character
def num_to_char(num):
    return chars[num]


# Decryption function
def decrypt(cipher_text, key):
    # Ensure the key length is at least as long as the ciphertext
    if len(key) < len(cipher_text):
        raise ValueError("Key length must be greater than or equal to ciphertext length")
    
    # Perform modular subtraction
    plaintext = ''
    for i in range(len(cipher_text)):
        cipher_num = char_to_num(cipher_text[i])
        key_num = char_to_num(key[i])
        plain_num = (cipher_num - key_num) % 26
        plaintext += num_to_char(plain_num)
    
    return plaintext

# Taking input from the user
#plaintext = input("Enter the plaintext (only capital letters): ")
key = "THISISANEXAMPLEKEYINCOMPUTERSECURITYEXAM"

# Decrypt the cipher text
cipher_text = input("Enter the cipher text (only capital letters): ")
decrypted_text = decrypt(cipher, key)
print(f"Decrypted text: {decrypted_text}")
# Out:
# Enter the cipher text (only capital letters): NANCY
# Decrypted text: NANCY
